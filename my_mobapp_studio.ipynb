# %%
# %pip install plotly
# %pip install pandas
# %pip install numpy
# %pip install plotly-express
# Out:
# ...
#
# ...
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd 
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
def load_dataset():
    data_fm = pd.read_csv('C:/Users/user/Desktop/My_mob_app/googleplaystore.csv')
    data_fm.drop(['Last Updated',"Current Ver", "Android Ver"],axis=1, inplace=True)
    return data_fm
apps = load_dataset()
apps.head(20)
# Out:
#                                                   App        Category  Rating  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                 Coloring book moana  ART_AND_DESIGN     3.9
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                               Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4               Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                          Paper flowers instructions  ART_AND_DESIGN     4.4
# 6             Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                    Infinite Painter  ART_AND_DESIGN     4.1
# 8                                Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                       Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
# 10                            Text on Photo - Fonteee  ART_AND_DESIGN     4.4
# ...

# %%
def print_summarize_dataset(dataset):
    print("This is details about dataset")
    print(dataset.info())
    
    print("This is statistic facts about dataset",dataset.describe())
    print("This is figures of dataset:",dataset.shape)

# %%
print_summarize_dataset(apps)
# Out:
# This is details about dataset
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 847.1+ KB
# None
# This is statistic facts about dataset             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000
# ...

# %%
def change_size_kb(row):
    if type(row) ==str:
        if row[-1].lower() == "k":
            row = row.replace('k', '')
            return float(row[:-1]) / 1024
        elif row[-1].lower() == "m":
            row = row.replace('M', '')
            return float(row[:-1])
        elif row.isalpha():
            return None
    return row

# %%
def clean_dataset(data_st):
    data_st = data_st.drop_duplicates(subset=["App"], keep='last')
    data_st["App"] = data_st["App"].str.replace('&', '-')
    data_st = data_st[data_st['Category'] != '1.9']
    data_st["Category"]=data_st["Category"].str.replace("_"," ")
    data_st["Category"]= data_st["Category"].apply(lambda x: x.capitalize())
    filtration= {'Everyone 10+': 'Everyone','Adults only 18+': 'Adults only','"': '', ',': '', ';': ' ','Mature 17+': 'Mature', 'and up': '','Unrated': 'NaN','Varies with device': 'NaN'}
    data_st.replace(filtration, regex=True, inplace=True)
    data_st["Rating"]= data_st["Rating"].astype(float)
    data_st["Reviews"]= data_st["Reviews"].astype(float)
    data_st["Size"]= data_st["Size"].apply(change_size_kb)
    data_st['Size'].replace('Varies with device', np.nan, inplace=True)
    data_st['Size'] = pd.to_numeric(data_st['Size'], errors='coerce')
    data_st['Size'].fillna(data_st['Size'].mean(), inplace=True)
    data_st["Installs"]= data_st["Installs"].str.replace("+", "").str.replace(",","").astype(int)
    data_st.rename(columns={'Type': 'Payment'}, inplace=True)
    data_st["Price"] = data_st["Price"].str.replace('$','').astype(float)
    data_st['Content Rating'] = data_st['Content Rating'].str.replace(r'[+]', '', regex=True)
    data_st['Content Rating'] = data_st['Content Rating'].str.replace('NaN', 'Unrated')
    data_st["Genres"] = data_st["Genres"].str.replace("&",'-')
    data_st['Popularity'] = data_st.Rating *10**7  * data_st.Reviews *10**2 * data_st.Installs
    data_st.dropna(inplace=True)
    return data_st

# %%
cleaned_apps = clean_dataset(apps)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8816\1910280471.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_st["App"] = data_st["App"].str.replace('&', '-')
# C:\Users\user\AppData\Local\Temp\ipykernel_8816\1910280471.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
cleaned_apps
# Out:
#                                                      App             Category  \
# 0         Photo Editor - Candy Camera - Grid - ScrapBook       Art and design
# 2      U Launcher Lite – FREE Live Cool Themes Hide Apps       Art and design
# 3                                  Sketch - Draw - Paint       Art and design
# 4                  Pixel Draw - Number Art Coloring Book       Art and design
# 5                             Paper flowers instructions       Art and design
# ...                                                  ...                  ...
# 10834                                      FR Calculator               Family
# 10836                                   Sya9a Maroc - FR               Family
# 10837                   Fr. Mike Schmitz Audio Teachings               Family
# 10839                      The SCP Foundation DB fr nn5n  Books and reference
# 10840      iHoroscope - 2018 Daily Horoscope - Astrology            Lifestyle
#
# ...

# %%
def print_histograms(data_st):
    fig = make_subplots(rows=1, cols=2,
                        subplot_titles=[ "Popularity of Genres", "Installs of Genres"],
                        column_widths=[1,1], row_heights=[0.5])
    fig.add_trace(go.Histogram(x=data_st['Genres'], y=data_st['Popularity']), row=1, col=1)
    fig.add_trace(go.Histogram(x=data_st['Genres'], y=data_st['Installs']), row=1, col=2)
    fig.update_layout(width=1300, height=600)
    fig.show()
    fig = px.histogram(cleaned_apps, x='Category', y='Rating', title='The rating  of  category',color='Rating',barmode='group',width=1200, height=600)
    fig.show()

# %%
print_histograms(cleaned_apps)

# %%
def compute_correlations_matrix(dataset):
    corr_dataset= dataset.corr( numeric_only=True)
    df= px.imshow(corr_dataset,title='Correlation of DataFrame',text_auto=True, width=1000,height=800,aspect= 'equal')
    df.show()

# %%
compute_correlations_matrix(cleaned_apps)

# %%
def print_scatter_matrix():
    scat_m = px.scatter(cleaned_apps, x='Category', y='Installs', width=800, height=500, color='Category', title='Total installation of category')
    scat_m.show()

# %%
print_scatter_matrix()

# %%
family_paid = cleaned_apps[(cleaned_apps['Category'] == "Family") & (cleaned_apps['Payment'] != 'Free')]
family_paid.sort_values(by="Installs", inplace=True, ascending=False)
family_paid.reset_index(inplace=True)
family_paid.drop("index", axis=1, inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8816\3598275199.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\user\AppData\Local\Temp\ipykernel_8816\3598275199.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
top_20_f_pd= family_paid.sort_values(by="Installs", ascending=False).head(20)
top_20_f_pd
# Out:
#                                 App Category  Rating    Reviews      Size  \
# 0                         Minecraft   Family     4.5  2375336.0  3.442205
# 4                 Cut the Rope GOLD   Family     4.6    61264.0  4.000000
# 5              Infinity Dungeon VIP   Family     4.3    21804.0  4.000000
# 1                 Where's My Water?   Family     4.7   188740.0  6.000000
# 3                       Bloons TD 5   Family     4.6   190086.0  9.000000
# 2        Card Wars - Adventure Time   Family     4.3   129603.0  2.000000
# 6         Five Nights at Freddy's 2   Family     4.6    73919.0  4.000000
# 7              Farming Simulator 16   Family     4.2    32812.0  1.000000
# 8             NBA JAM by EA SPORTS™   Family     4.3    56444.0  4.000000
# 9                         Hitman GO   Family     4.6    84114.0  2.000000
# 10                  Toca Life: City   Family     4.7    31100.0  2.000000
# 29        Dr. Panda's Swimming Pool   Family     4.4     2311.0  9.000000
# ...

# %%
fig0 = px.bar(top_20_f_pd, x='App', y='Installs', title="  The most populars paid apps of Family category ", color='App')
fig0.show()

# %%
num_ll_each_category = cleaned_apps.groupby(by="Category").sum()
nbr_ll_per_category_top_15 = num_ll_each_category.sort_values(by="Installs", ascending=False).head(15)

# %%
nbr_ll_per_category_top_15
# Out:
#                                                                    App  \
# Category
# Communication        Messenger for SMSMy Tele2ContactsCall Free – F...
# Game                 Bubble Witch 3 SagaRace the Traffic MotoMarble...
# Family               Candy BombJewels Crush- Match 3 PuzzleColoring...
# Tools                Moto DisplayMotorola AlertMotorola AssistMoto ...
# Productivity         All-In-One Toolbox: Cleaner Booster App Manage...
# Social               Social network all in one 2018The Messenger Ap...
# Photography          TouchNote: Cards - GiftsFreePrints – Free Phot...
# Video players        All Video Downloader 2018HD Video PlayerIqiyi ...
# Travel and local     TripIt: Travel OrganizerTrip by Skyscanner - C...
# News and magazines   NEW - Read Newspaper News 24hBaBe + - Indonesi...
# Books and reference  E-Book Read - Read Book for freeDownload free ...
# Personalization      Funny RingtonesXOS - LauncherThemeWallpaper3D ...
# ...

# %%
fig1=px.pie(nbr_ll_per_category_top_15,values= 'Installs', names = nbr_ll_per_category_top_15.index,  title='The number of installation per category', color='Installs')
fig1.show()

# %%
mean_price_each_category = cleaned_apps.groupby(by="Category")['Price'].mean()
mean_price_each_category.sort_values(ascending=False).head(15)
# Out:
# Category
# Finance                8.079040
# Lifestyle              6.514551
# Medical                2.099244
# Family                 1.351457
# Personalization        0.417047
# Weather                0.408750
# Sports                 0.355763
# Game                   0.315552
# Tools                  0.288750
# Photography            0.274943
# Business               0.245840
# Productivity           0.235615
# Maps and navigation    0.228390
# Communication          0.220584
# Travel and local       0.200481
# Name: Price, dtype: float64

# %%
fig2=px.bar(mean_price_each_category, x=mean_price_each_category.index, y='Price', title='The main price per category', color='Price')
fig2.show()

# %%
df=cleaned_apps.sort_values(by='Price',ascending=False).head(15)
fig3=px.sunburst(df, path=['Category','App'], values='Price')
fig3.update_layout(title=' Most expensive apps per category')
fig3.show()
